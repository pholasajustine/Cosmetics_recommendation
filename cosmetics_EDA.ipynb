# %% [markdown]
# #### Libraries

# %%
import numpy as np
import pandas as pd
import scipy.stats as st
import statsmodels as sm
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Let's read our new dataset

# %%
data = pd.read_csv('./Data/cosmetics_cleaned.csv')

# %%
data.head()
# Out:
#          Label           Brand                                           Name  \
# 0  Moisturizer          LA MER                                Crème de la Mer
# 1  Moisturizer           SK-II                       Facial Treatment Essence
# 2  Moisturizer  DRUNK ELEPHANT                     Protini™ Polypeptide Cream
# 3  Moisturizer          LA MER                    The Moisturizing Soft Cream
# 4  Moisturizer    IT COSMETICS  Your Skin But Better™ CC+™ Cream with SPF 50+
#
#    Price  Rank                                        Ingredients  \
# 0    175   4.1  Algae (Seaweed) Extract, Mineral Oil, Petrolat...
# 1    179   4.1  Galactomyces Ferment Filtrate (Pitera), Butyle...
# 2     68   4.4  Water, Dicaprylyl Carbonate, Glycerin, Ceteary...
# 3    175   3.8  Algae (Seaweed) Extract, Cyclopentasiloxane, P...
# 4     38   4.1  Water, Snail Secretion Filtrate, Phenyl Trimet...
#
#    Combination  Dry  Normal  Oily  Sensitive  Harmful_Substances  \
# 0            1    1       1     1          1                  10
# 1            1    1       1     1          1                   1
# 2            1    1       1     1          0                   1
# 3            1    1       1     1          1                  12
# 4            1    1       1     1          1                   5
#
#                                        ing_processed
# 0  ['petrolatum', 'magnesium sulfate', 'eucalyptu...
# 1  ['pentylene glycol', 'methylparaben', 'water',...
# 2  ['', 'glycine', 'arginine', 'sh-oligopeptide-'...
# 3  ['petrolatum', 'copper gluconate', 'pentylene ...
# 4  ['', 'thiamine hcl', 'tocopherol', 'aluminum h...

# %% [markdown]
# ## 1. Univariate analysis

# %% [markdown]
# #### Numerical variables

# %% [markdown]
# We are creating df_numeric which will only contain the numerical variables

# %%
df_numeric = data[['Price', 'Rank', 'Harmful_Substances']]

# %%
sns.displot(df_numeric['Price'], bins=50, kde=True, rug=True)
sns.displot(df_numeric['Rank'], bins=50, kde=True, rug=True)
sns.displot(df_numeric['Harmful_Substances'], bins=50, kde=True, rug=True)

# %%
We have a right skewed distibution

# %%
sns.pairplot(df_numeric)

# %% [markdown]
# It doesn't look like there is a relation between the 3 variables
